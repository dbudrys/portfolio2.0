# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df= pd.read_csv("clusterCenters.csv", sep= ",")

# %%
df=df.sort_values(by=['AverageMinPerGame'])
df
# Out:
#     AveragePointsPerGame  AverageMinPerGame
# 12              0.926126           2.809212
# 33              1.400668           4.931883
# 18              2.373227           6.445232
# 5               1.744301           8.135968
# 16              3.267434           8.601859
# 28              4.559564          10.262867
# 26              2.508099          10.354266
# 1               3.832477          11.780973
# 44              5.424288          12.929888
# 46              2.987958          13.176295
# 36              4.561702          14.676938
# 4               6.817157          15.364195
# 29              3.281444          16.357111
# 45              5.352982          16.899481
# 38              7.426364          17.866607
# 35              4.696932          19.106787
# 8               9.565978          19.807204
# 11              6.820254          20.077329
# 10              8.164319          21.984729
# 19              5.437615          22.614851
# ...

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20,3)

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (18,8)

xMin = range(0, 49)
yPTS = range(0, 55, 5)

lines = df.plot(x='AverageMinPerGame', y='AveragePointsPerGame', fontsize=14, 
                title="Comparison of minutes vs points in the NBA", 
                xticks=xMin, yticks=yPTS
               )


lines.set_xlabel("Average Minutes Played per Game")
lines.set_ylabel("Average Points Scored per Game")
# Out:
# Text(0,0.5,'Average Points Scored per Game')
